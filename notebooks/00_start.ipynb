# %% [markdown]
# # Jupyter Notebook project
#
# Startpunt voor het project. De inhoud, dataset en onderzoeksvraag volgen in de volgende instructies.

# %% [markdown]
# ## Omgeving
#
# Deze notebook gebruikt de Python-omgeving van het project. Houd verkennende stappen, aannames en conclusies overzichtelijk bij in markdown-cellen.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
print(f"Notebookomgeving is klaar: {PROJECT_ROOT}")
